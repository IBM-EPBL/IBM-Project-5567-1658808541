# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %% [markdown]
# # **2. Load the Dataset**

# %%
from pandas import read_csv
data = read_csv("Churn_Modelling_1.csv")

# %% [markdown]
# # **3.1. Univariate Analysis**

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       NaN              1          1               1
# 1       1   8387.86              1          0               1
# 2       8  15966.80              3          1               0
# 3       1       NaN              2          0               0
# 4       2  12551.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
#Histogram
df.hist(column='CreditScore', grid=False, edgecolor='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0567481fd0>]],
#       dtype=object)

# %% [markdown]
# # **3.2. Bi-Variate Analysis**

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# ## **There are three ways to use Bi-Variate Analysis**
# ### 1. Scatterplots
# ### 2. Correlation Coefficients
# ### 3. Simple Linear Regression

# %%
#1. Scatterplots

plt.scatter(df.CreditScore, df.Balance)
plt.title('CreditScore vs. Balance')
plt.xlabel('CreditScore')
plt.ylabel('Balance')
# Out:
# Text(0, 0.5, 'Balance')

# %%
#2. Correlation Coefficients

df.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202    -0.000104  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.006785  0.009497 -0.014883
# CreditScore      -0.000104    0.006785     1.000000 -0.006486  0.002820
# Age               0.000783    0.009497    -0.006486  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.002820 -0.009997  1.000000
# Balance           0.022852    0.005169    -0.002128 -0.000892  0.008298
# NumOfProducts     0.007246    0.016972     0.013077 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.003184 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025528  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001242 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.026929  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber        0.022852       0.007246   0.000599        0.012044
# CustomerId       0.005169       0.016972  -0.014025        0.001665
# CreditScore     -0.002128       0.013077  -0.003184        0.025528
# Age             -0.000892      -0.030680  -0.011721        0.085472
# Tenure           0.008298       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.016715   0.001500       -0.011732
# NumOfProducts   -0.016715       1.000000   0.003183        0.009612
# HasCrCard        0.001500       0.003183   1.000000       -0.011866
# IsActiveMember  -0.011732       0.009612  -0.011866        1.000000
# EstimatedSalary  0.021271       0.014204  -0.009933       -0.011421
# Exited          -0.016424      -0.047820  -0.007138       -0.156128
#
#                  EstimatedSalary    Exited
# RowNumber              -0.005988 -0.016571
# CustomerId              0.015271 -0.006248
# CreditScore            -0.001242 -0.026929
# Age                    -0.007201  0.285323
# Tenure                  0.007784 -0.014001
# Balance                 0.021271 -0.016424
# NumOfProducts           0.014204 -0.047820
# HasCrCard              -0.009933 -0.007138
# IsActiveMember         -0.011421 -0.156128
# EstimatedSalary         1.000000  0.012097
# Exited                  0.012097  1.000000

# %%
#3. Simple Linear Regression

x=df['CreditScore']
y=df['Age']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4206
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):              0.517
# Time:                        18:29:36   Log-Likelihood:                -37691.
# No. Observations:               10000   AIC:                         7.539e+04
# Df Residuals:                    9998   BIC:                         7.540e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          39.3737      0.705     55.875      0.000      37.992      40.755
# CreditScore    -0.0007      0.001     -0.649      0.517      -0.003       0.001
# ==============================================================================
# Omnibus:                     1509.404   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2518.540
# Skew:                           1.012   Prob(JB):                         0.00
# Kurtosis:                       4.397   Cond. No.                     4.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# #**3.3. Multi - Variate Analysis**

# %%
pd.plotting.scatter_matrix(data.loc[:, "CreditScore":"Balance"], diagonal="kde",figsize=(20,15))
plt.show()

# %%
ax = data[["CreditScore","Age","NumOfProducts","Balance"]].plot(figsize=(20,15))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# #4. Descriptive statistics.

# %%
# Mean
data[["CreditScore","Age","NumOfProducts","Balance"]].mean()
# Out:
# CreditScore        650.862500
# Age                 38.921800
# NumOfProducts        1.530200
# Balance          75345.698833
# dtype: float64

# %%
# Median
data[["CreditScore","Age","NumOfProducts","Balance"]].median()
# Out:
# CreditScore        652.00
# Age                 37.00
# NumOfProducts        1.00
# Balance          85225.21
# dtype: float64

# %%
# Mode
from collections import Counter
CreditScore = data['CreditScore'].values
data1 = dict(Counter(CreditScore))
mode = [k for k, v in data1.items() if v == max(list(data1.values()))]
mode
# Out:
# [850]

# %%
# Standard Deviation
np.std(CreditScore)
# Out:
# 97.96337781921365

# %% [markdown]
# # **5. Handle the Missing values.**

# %%
# To find the total number of Missing values
data.isnull().sum().sum()
# Out:
# 3617

# %% [markdown]
# ## **There are 2 primary ways of handling missing values:**
#
# ### 1. Deleting the Missing values
# ### 2. Imputing the Missing Values

# %%
# 1. Deleting the Missing values
miss=data.dropna(axis=0)
miss.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# 2. Imputing the Missing Values
# Replace with 0
data['Balance'] = data['Balance'].fillna(0)
data['Balance'].isnull().sum()
# Out:
# 0

# %%
# Replace with Mean Value
data['Balance'] = data['Balance'].fillna(data['Balance'].mean())
data['Balance'].isnull().sum()
# Out:
# 0

# %%
# Replace with Mode Value
data['Balance'] = data['Balance'].fillna(data['Balance'].mode())
data['Balance'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # **6. Find the outliers and replace the outliers**

# %%
sns.boxplot(data['CreditScore'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Here the Points away from the line are Outliers

# %%
print("Index of Outliers")
np.where(data['CreditScore']>1000)
# Out:
# Index of Outliers
# (array([11, 17, 22, 34, 56]),)

# %%
data.drop(['CreditScore'],axis=1,inplace=False)
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1   8387.86              1          0               1
# 2       8  15966.80              3          1               0
# 3       1      0.00              2          0               0
# 4       2  12551.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data['CreditScore'].isnull().sum()
# Out:
# 0

# %%
data['CreditScore'] = data['CreditScore'].fillna(data['CreditScore'].mode())
data['CreditScore'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # **7. Check for Categorical columns and perform encoding.**

# %%
print("Gender:")
print(data["Gender"].value_counts())
print()
print("Number of Products:")
print(data["NumOfProducts"].value_counts())
# Out:
# Gender:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
#
# Number of Products:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64

# %%
data["NumOfProducts"] = np.where(data["Gender"].str.contains("Female"), 2, 0)
data[["NumOfProducts", "Gender"]].head()
# Out:
#    NumOfProducts  Gender
# 0              2  Female
# 1              2  Female
# 2              2  Female
# 3              2  Female
# 4              2  Female

# %% [markdown]
# # **8. Split the data into dependent and independent variables.**

# %%
# Independent Feature Matrix
A = data.iloc[:, :-1].values
print(A)
# Out:
# [[1 15634602 'Hargrave' ... 1 1 101348.88]
#  [2 15647311 'Hill' ... 0 1 112542.58]
#  [3 15619304 'Onio' ... 1 0 113931.57]
#  ...
#  [9998 15584532 'Liu' ... 0 1 42085.58]
#  [9999 15682355 'Sabbatini' ... 1 0 92888.52]
#  [10000 15628319 'Walker' ... 1 0 38190.78]]

# %%
# Dependent Feature Matrix
B = data.iloc[:, -1].values
print(B)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# # **9. Scale the independent variables**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.hist(column='CreditScore', grid=False, color='blue')
df.hist(column='Exited', grid=False, color='orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0566dfd8d0>]],
#       dtype=object)

# %% [markdown]
# # **10. Split the data into training and testing**

# %%
from sklearn.model_selection import train_test_split
features = ["CreditScore","Age","NumOfProducts","Balance"]
X = data.loc[:, features]
y = data.loc[:, ['EstimatedSalary']]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = .75)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth = 2, random_state = 0)
reg.fit(X_train, y_train)
print("Training Data",reg.predict(X_train[0:10]))
print("\n",y_train)
print("Testing Data",reg.predict(X_test[0:10]))
print("\n",y_test)
# Out:
# Training Data [100244.64560416 100244.64560416 100244.64560416 100244.64560416
#  100244.64560416 100244.64560416 100244.64560416 100244.64560416
#  100244.64560416 100244.64560416]
#
#        EstimatedSalary
# 2967          5831.00
# 700          95611.47
# 3481         42855.97
# 1621          8651.92
# 800         173952.50
# ...               ...
# 9225        162961.79
# 4859        107753.07
# 3264        181429.87
# 9845        148750.16
# 2732        118855.26
#
# [7500 rows x 1 columns]
# Testing Data [100244.64560416 100244.64560416 100244.64560416 100244.64560416
#  100244.64560416 100244.64560416 100244.64560416 100244.64560416
#  100244.64560416 100244.64560416]
#
#        EstimatedSalary
# 9394        192852.67
# 898         128702.10
# 2398         75732.25
# 5906         89368.59
# 2343        135662.17
# ...               ...
# 8764         86701.40
# 4359        108398.63
# 2041         84487.62
# 1108         46522.68
# 3332         72927.68
#
# [2500 rows x 1 columns]
